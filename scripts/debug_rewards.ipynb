# %%
import os
import json
import sys

sys.path.append("/home/arnaik/OracleProject")

from src.dpo.reward_model_newformat import evaluate_instance
from src.metrics.meta_linting import

# %%
cd /home/arnaik/OracleProject
# Out:
# /home/arnaik/OracleProject

# %%
debug_data = json.load(open("data/dpo_data_troubleshoot.json"))

# %%
truth = debug_data['data'][32]['chosen'][1]['content']

# %%
resp = debug_data['data'][32]['rejected'][0]['content']

# %%
evaluate_instance(resp, truth)
# Out:
# 0.8
